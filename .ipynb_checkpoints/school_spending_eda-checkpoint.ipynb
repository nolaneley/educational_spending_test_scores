# %% [markdown]
# # School spending versus outcome EDA
# ### Import packages

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pygal

# %% [markdown]
# ### Import data

# %%
df = pd.read_csv('school_spending_outcome.csv')
df.sort_values('states_abbrev')
# Out:
#                    state states_abbrev      spending  pct_valid    math  \
# 27                Alaska            AK  19810.211650   0.844794  274.34
# 42               Alabama            AL  10147.715700   0.954341  268.70
# 24              Arkansas            AR  10031.048730   0.922303  274.36
# 43               Arizona            AZ   8607.740000   0.503012  279.93
# 31            California            CA  13015.595085   0.487838  275.61
# 23              Colorado            CO  11283.832800   0.867973  284.67
# 0            Connecticut            CT  20765.788375   0.900778  286.16
# 45  District of Columbia            DC  22189.955440   0.809129  269.18
# 28              Delaware            DE  15177.698093   0.886463  276.70
# 15               Florida            FL   9696.000000   0.808531  278.52
# 7                Georgia            GA  11487.868035   0.956596  279.49
# 14                Hawaii            HI  16284.300285   0.996587  275.33
# 44                  Iowa            IA  11726.053480   0.080816  281.67
# 38                 Idaho            ID   8023.462703   0.821522  285.94
# 48              Illinois            IL  15133.818211   0.639854  282.56
# 20               Indiana            IN  10109.813745   0.858171  285.65
# 46                Kansas            KS  11624.439980   0.763098  282.21
# 37              Kentucky            KY  11503.020088   0.354545  278.10
# 25             Louisiana            LA  11698.338780   0.934579  271.64
# 40         Massachusetts            MA  17130.944520   0.862587  294.47
# 41              Maryland            MD  15104.860780   0.955213  280.15
# 1                  Maine            ME  14692.882840   0.913399  282.37
# 39              Michigan            MI  10819.000000   0.881093  280.28
# 12             Minnesota            MN  11858.321348   0.690493  290.79
# 30              Missouri            MO  10381.310430   0.802264  280.76
# 17           Mississippi            MS   9257.553069   0.796949  273.73
# 49               Montana            MT  12616.216220   0.917775  283.96
# 6         North Carolina            NC  10212.226150   0.944978  283.66
# 4           North Dakota            ND  14608.612540   0.959350  285.56
# 21              Nebraska            NE  13417.000000   0.740570  285.01
# 18         New Hampshire            NH  18577.436655   0.935927  287.22
# 19            New Jersey            NJ  20050.134236   0.874372  291.82
# 36            New Mexico            NM  10509.823995   0.854566  268.77
# 16                Nevada            NV   9524.488825   0.820755  273.79
# 8               New York            NY  25358.034195   0.891828  280.41
# 3                   Ohio            OH  12446.650280   0.957673  285.71
# 26              Oklahoma            OK   9455.949327   0.958495  276.47
# 11                Oregon            OR  12619.366465   0.549922  279.50
# 10          Pennsylvania            PA  15255.582020   0.794147  285.02
# 13          Rhode Island            RI  17141.221910   0.802941  275.67
# 47        South Carolina            SC  10967.440290   0.739715  276.35
# 34             Tennessee            TN   9806.492105   0.920719  280.08
# 5                  Texas            TX   9795.418073   0.916884  279.65
# 2                   Utah            UT   7842.160622   0.864717  284.93
# 22              Virginia            VA  12048.042795   0.812058  287.06
# 33               Vermont            VT  14631.115790   0.324759  286.60
# 9             Washington            WA  14338.336640   0.830529  285.81
# 35             Wisconsin            WI  12484.137385   0.870013  288.66
# 32         West Virginia            WV  12112.640405   0.902069  272.35
# 29               Wyoming            WY  16906.461410   0.965418  286.31
#
#     reading
# 27   252.39
# 42   253.40
# 24   258.78
# 43   259.48
# 31   258.83
# 23   267.31
# 0    269.72
# 45   249.81
# 28   259.68
# 15   263.35
# 7    262.39
# 14   258.16
# 44   262.33
# 38   266.48
# 48   264.70
# 20   265.95
# 46   262.82
# 37   262.96
# 25   257.42
# 40   273.11
# 41   264.39
# 1    265.17
# 39   262.58
# 12   263.81
# 30   263.29
# 17   256.38
# 49   264.83
# 6    262.53
# 4    263.23
# 21   263.99
# 18   267.95
# 19   270.36
# 36   251.70
# 16   258.08
# 8    261.75
# 3    267.05
# 26   258.20
# 11   263.72
# 10   264.18
# 13   262.15
# 47   258.98
# 34   262.46
# 5    255.74
# 2    267.42
# 22   261.80
# 33   268.48
# 9    266.28
# 35   267.38
# 32   255.62
# 29   264.64

# %% [markdown]
# ### Plot distributions of spending and math and reading scores

# %%
# Spending distribution
sns.displot(df.spending, kde=True, color='#5F7DA5')
plt.title('Educational spending distribution')
plt.xlabel('Educational spending ($)')

# Math scores distribution
sns.displot(df.math, kde=True, color='#5F7DA5')
plt.title('Math scores distribution')
plt.xlabel('Math scores')

# Reading scores distribution
sns.displot(df.reading, kde=True, color='#5F7DA5')
plt.title('Reading scores distribution')
plt.xlabel('Reading scores')
# Out:
#   Cell In[10], line 7
#     sns.displot(df.math, kde=True, color='#5F7DA5'))
#                                                    ^
# SyntaxError: unmatched ')'

# %% [markdown]
# ### Use seaborn regplot to plot spending vs math and reading scores

# %%
# Spending vs math plot
sns.regplot(x=df.spending, y=df.math, color='#5F7DA5')
plt.title('Spending versus math scores')
plt.xlabel("Spending ($)")
plt.ylabel("Math score")
plt.show()

# Spending vs reading plot
sns.regplot(x=df.spending, y=df.reading, color='#5F7DA5')
plt.title('Spending versus reading scores')
plt.xlabel("Spending ($)")
plt.ylabel("Reading score")
plt.show()

# %% [markdown]
# ### Plot median spending versus avg math scores

# %%
plt.scatter(df.spending, df.math)
plt.title("Spending versus outcome in MATH")
plt.xlabel("Median per pupil spending ($)")
plt.ylabel("Average math score")
# Out:
# Text(0, 0.5, 'Average math score')

# %% [markdown]
# ### Plot median spending versus avg reading scores

# %%
plt.scatter(df.spending, df.reading)
plt.title("Spending versus outcome in READING")
plt.xlabel("Median per pupil spending ($)")
plt.ylabel("Average reading score")
# Out:
# Text(0, 0.5, 'Average reading score')

# %% [markdown]
# ### Try pygal scatter plot

# %%
xy_chart = pygal.XY(stroke=False)
for state, spend, m_score in zip(df.states_abbrev.values[:10],df.spending.values[:10],df.math.values[:10]):
    print(state)
    print(spend)
    print(m_score)
    #     xy_chart.add(state, [(spend, m_score)])
# xy_chart.render()
# Out:
# CT
# 20765.788375
# 286.16
# ME
# 14692.88284
# 282.37
# UT
# 7842.160622
# 284.93
# OH
# 12446.65028
# 285.71
# ND
# 14608.61254
# 285.56
# TX
# 9795.418073
# 279.65
# NC
# 10212.22615
# 283.66
# GA
# 11487.868035
# 279.49
# NY
# 25358.034195
# 280.41
# WA
# 14338.33664
# 285.81

# %% [markdown]
# ### Fit linear regression to spending—math relationship

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import f_regression
from sklearn.feature_selection import r_regression

# Convert to numpy arrays for easier processing
spending = np.array(df.spending)
math = np.array(df.math)

# Expand dimensions to fit into sklearn regression
spending = np.expand_dims(spending, axis=1)
math = np.expand_dims(math, axis=1)

# Create regression object
regression = LinearRegression()
regression.fit(spending, math)

# Plot scatter plot with regression line
x = np.linspace(min(spending),max(spending),50)
plt.scatter(spending, math, color='#5F7DA5')
plt.plot(x, regression.predict(x), color='#B07571')
plt.title("Spending versus outcome in MATH")
plt.xlabel("Median per pupil spending ($)")
plt.ylabel("Average math score")

# Calculate and print MSE and slope
mse = mean_squared_error(math, regression.predict(spending))
print('Mean Squared Error: ', mse)
print('Slope: ', regression.coef_[0])

# Calculate f-stat and p-value

r_math = r_regression(spending,math)
_, p_math = f_regression(spending,math)

print("r math: ", str(r_math))
print("p math: ", str(p_math))
# Out:
# Mean Squared Error:  34.82476716526683
# Slope:  [0.00023218]
# r math:  [0.14806306]
# p math:  [0.30481958]
# /usr/local/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Fit linear regression to spending—reading relationship

# %%
# Get reading scores as array and reshape
reading = np.array(df.reading)
reading = np.expand_dims(reading, axis=1)

# Create regression object
regression = LinearRegression()
regression.fit(spending, reading)

# Plot scatter plot with regression line
plt.scatter(spending, reading)
plt.plot(spending, regression.predict(spending), color='red')
plt.title("Spending versus outcome in READING")
plt.xlabel("Median per pupil spending ($)")
plt.ylabel("Average reading score")

# Calculate and print MSE and slope
mse = mean_squared_error(reading, regression.predict(spending))
print('Mean Squared Error: ', mse)
print('Slope: ', regression.coef_[0])

# Calculate f stat and p-value
r_reading = r_regression(spending, reading)
_, p_reading = f_regression(spending,reading)
print("r reading: ", str(r_reading))
print("p reading: ", str(p_reading))
# Out:
# Mean Squared Error:  23.528073852336355
# Slope:  [0.00015091]
# r reading:  [0.11756762]
# p reading:  [0.41614499]
# /usr/local/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.11/site-packages/sklearn/utils/validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ### Fit polynomial regression to spending—math relationship

# %%
from sklearn.preprocessing import PolynomialFeatures
n = 2 # polynomial degree
poly_feats = PolynomialFeatures(degree=n)
s_poly = poly_feats.fit_transform(spending)

regression = LinearRegression()
regression.fit(s_poly, math)

# Plot scatter plot with regression line
plt.scatter(spending, math, color='#5F7DA5')
x_poly = poly_feats.fit_transform(x)
plt.plot(x, regression.predict(x_poly), color='#B07571')
plt.title("Spending versus outcome in MATH")
plt.xlabel("Median per pupil spending ($)")
plt.ylabel("Average math score")

# Calculate and print MSE and slope
mse = mean_squared_error(math, regression.predict(s_poly))
print('Mean Squared Error: ', mse)
# Out:
# Mean Squared Error:  33.37659075264251

# %% [markdown]
# ### Fit polynomial regression to spending—reading relationship

# %%
regression = LinearRegression()
regression.fit(s_poly, reading)

# Plot scatter plot with regression line
plt.scatter(spending, reading, color='#5F7DA5')
x = np.linspace(min(spending),max(spending),50)
x_poly = poly_feats.fit_transform(x)
plt.plot(x, regression.predict(x_poly), color='#B07571')
plt.title("Spending versus outcome in READING")
plt.xlabel("Median per pupil spending ($)")
plt.ylabel("Average reading score")

# Calculate and print MSE and slope
mse = mean_squared_error(reading, regression.predict(s_poly))
print('Mean Squared Error: ', mse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 regression = LinearRegression()
# ----> 2 regression.fit(s_poly, reading)
#       4 # Plot scatter plot with regression line
#       5 plt.scatter(spending, reading, color='#5F7DA5')
#
# NameError: name 'reading' is not defined

# %% [markdown]
# ### Find 10 states with best ratio of spending to math and reading outcomes

# %%
# Calculate ratios and get sorted indices to apply to states list
rat_math = np.squeeze(spending) / np.squeeze(math)
rat_reading = np.squeeze(spending) / np.squeeze(reading)
sorted_indices_math = sorted(range(len(rat_math)), key=lambda i: rat_math[i])
sorted_indices_read = sorted(range(len(rat_reading)), key=lambda i: rat_reading[i])

states = df.state # list of states in original (arbitrary)

# Show top ratios for math and reading
states_math_sorted = [states[i] for i in sorted_indices_math]
print("\n10 best spending-to-outcome ratio in math:")
[print(state) for state in states_math_sorted[0:10]]

states_read_sorted = [states[i] for i in sorted_indices_read]
print("\n10 best spending-to-outcome ratio in reading:")
[print(state) for state in states_read_sorted[0:10]]
# Out:
# 10 best spending-to-outcome ratio in math:
# Utah
# Idaho
# Arizona
# Mississippi
# Oklahoma
# Nevada
# Florida
# Tennessee
# Texas
# Indiana
#
# 10 best spending-to-outcome ratio in reading:
# Utah
# Idaho
# Arizona
# Mississippi
# Oklahoma
# Florida
# Nevada
# Tennessee
# Indiana
# Texas
# [None, None, None, None, None, None, None, None, None, None]

# %% [markdown]
# ### Find 10 states with worst ratio of spending to math and reading outcomes

# %%
# Show top ratios for math and reading
states_math_sorted = [states[i] for i in sorted_indices_math]
print("\n10 worst spending-to-outcome ratio in math:")
[print(state) for state in states_math_sorted[-10:][::-1]]

states_read_sorted = [states[i] for i in sorted_indices_read]
print("\n10 worst spending-to-outcome ratio in reading:")
[print(state) for state in states_read_sorted[-10:][::-1]]
# Out:
# 10 worst spending-to-outcome ratio in math:
# New York
# District of Columbia
# Connecticut
# Alaska
# New Jersey
# New Hampshire
# Rhode Island
# Hawaii
# Wyoming
# Massachusetts
#
# 10 worst spending-to-outcome ratio in reading:
# New York
# District of Columbia
# Alaska
# Connecticut
# New Jersey
# New Hampshire
# Rhode Island
# Wyoming
# Hawaii
# Massachusetts
# [None, None, None, None, None, None, None, None, None, None]
